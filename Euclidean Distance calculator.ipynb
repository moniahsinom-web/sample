# %%
import numpy as np

# %% [markdown]
# # 1. Define the function

# %%
def euclidean_distance(v1, v2):
    # Convert to NumPy arrays
    v1 = np.array(v1)
    v2 = np.array(v2)
     
     #Compute the difference, square it, sum, and take the square root
    distance = np.sqrt(np.sum((v1 - v2) ** 2))
    return distance  # Make sure this line is indented by exactly 4 spaces

# %%
# Example usage
vector1 = [3, 5, 2]
vector2 = [1, 1, 4]

# Calculate Euclidean distance
dist = euclidean_distance(vector1, vector2)


print("Vector 1:", vector1)
print("Vector 2:", vector2)
print("Euclidean Distance:", dist)
# Out:
# Vector 1: [3, 5, 2]
# Vector 2: [1, 1, 4]
# Euclidean Distance: 4.898979485566356
