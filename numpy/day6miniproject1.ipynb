# %%
import numpy as np

# %% [markdown]
# # Step 1: Define the coefficient matrix A and constant vector b

# %%
A = np.array([[2, 3, -1],
              [4, 1, 2],
              [-2, 5, 3]])

b = np.array([5, 10, 1])

# %% [markdown]
# # Step 2: Solve for x using NumPy's linear algebra solver

# %%
print("Solution (x, y, z) =, x")
# Out:
# Solution (x, y, z) =, x
