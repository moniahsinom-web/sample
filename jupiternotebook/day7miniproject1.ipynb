# %% [markdown]
# # Student Gradebook

# %% [markdown]
# Create a DataFrame for student grades and calculate the average
# score for each student and each subject.

# %% [markdown]
# import libraray

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Sample data for student grades

# %%
data = {
    'Student': ['Alice', 'Bob', 'Alice', 'Bob', 'Charlie', 'Alice'],
    'Subject': ['Math', 'Math', 'Physics', 'Physics', 'Math', 'Chemistry'],
    'Score': [85, 70, 92, 65, 88, 78]
}

# %% [markdown]
# # Create the DataFrame

# %%
f = pd.DataFrame(data)

print("Original Gradebook:")

print (data)
# Out:
# Original Gradebook:
# {'Student': ['Alice', 'Bob', 'Alice', 'Bob', 'Charlie', 'Alice'], 'Subject': ['Math', 'Math', 'Physics', 'Physics', 'Math', 'Chemistry'], 'Score': [85, 70, 92, 65, 88, 78]}

# %% [markdown]
# # calculate students average

# %%
student_avarages= df .groupby('Student').mean() # type: ignore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 student_avarages= df .groupby('Student').mean() # type: ignore
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Create an alternative DataFrame where subjects are columns
